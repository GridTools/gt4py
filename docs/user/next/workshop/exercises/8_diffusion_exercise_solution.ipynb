# %%
from helpers import *

import gt4py.next as gtx

# %%
def diffusion_step_numpy(
    e2c2v: np.array,
    v2e: np.array,
    TE: np.array,
    TE_t: np.array,
    inv_primal_edge_length: np.array,
    inv_vert_vert_length: np.array,
    nnbhV: np.array,
    boundary_edge: np.array,
    kappa: float,
    dt: float,
) -> np.array:

    # initialize
    TEinit = TE

    # predict
    TE = TEinit + 0.5*dt*TE_t

    # interpolate temperature from edges to vertices
    TV = neighbor_sum(TE(v2e), axis=1) / nnbhV

    # compute nabla2 using the finite differences
    TEnabla2 = neighbor_sum(
        (TV(e2c2v[0]) + TV(e2c2v[1])) * inv_primal_edge_length ** 2
        + (TV(e2c2v[3]) + TV(e2c2v[4])) * inv_vert_vert_length ** 2,
        axis=1,
    )

    TEnabla2 = TEnabla2 - (
        (2.0 * TE * inv_primal_edge_length ** 2)
        + (2.0 * TE * inv_vert_vert_length ** 2)
    )

    # build ODEs
    TE_t = where(
        boundary_edge,
        0.,
        kappa*TEnabla2,
    )

    # correct
    TE = TEinit + dt*TE_t

# %%
@gtx.field_operator
def diffusion_step(
    TE: gtx.Field[Dims[E], float],
    TE_t: gtx.Field[Dims[E], float],
    inv_primal_edge_length: gtx.Field[Dims[E], float],
    inv_vert_vert_length: gtx.Field[Dims[E], float],
    nnbhV: gtx.Field[Dims[V], float],
    boundary_edge: gtx.Field[Dims[E], bool],
    kappa: float,
    dt: float,
) -> gtx.tuple[
    gtx.Field[Dims[E], float],
    gtx.Field[Dims[E], float],
]:

    # initialize
    TEinit = TE

    # predict
    TE = TEinit + 0.5*dt*TE_t

    # interpolate temperature from edges to vertices
    TV = neighbor_sum(TE(V2E), axis=V2EDim) / nnbhV

    # compute nabla2 using the finite differences
    TEnabla2 = neighbor_sum(
        (TV(E2C2V[0]) + TV(E2C2V[1])) * inv_primal_edge_length ** 2
        + (TV(E2C2V[3]) + TV(E2C2V[4])) * inv_vert_vert_length ** 2,
        axis=E2C2VDim,
    )

    TEnabla2 = TEnabla2 - (
        (2.0 * TE * inv_primal_edge_length ** 2)
        + (2.0 * TE * inv_vert_vert_length ** 2)
    )

    # build ODEs
    TE_t = where(
        boundary_edge,
        0.,
        kappa*TEnabla2,
    )

    # correct
    TE = TEinit + dt*TE_t
    
    return TE_t, TE
# Out:
# ---------------------------------------------------------------------------
# DSLError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 @gtx.field_operator
# ----> 2 def diffusion_step(
#       3     TE: gtx.Field[Dims[E], float],
#       4     TE_t: gtx.Field[Dims[E], float],
#       5     inv_primal_edge_length: gtx.Field[Dims[E], float],
#       6     inv_vert_vert_length: gtx.Field[Dims[E], float],
#       7     nnbhV: gtx.Field[Dims[V], float],
#       8     boundary_edge: gtx.Field[Dims[E], bool],
#       9     kappa: float,
#      10     dt: float,
#      11 ) -> gtx.tuple[
#      12     gtx.Field[Dims[E], float],
#      13     gtx.Field[Dims[E], float],
#      14 ]:
#      15
#      16     # initialize
#      17     TEinit = TE
#      19     # predict
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/decorator.py:794, in field_operator(definition, backend, grid_type)
#     789 def field_operator_inner(definition: types.FunctionType) -> FieldOperator[foast.FieldOperator]:
#     790     return FieldOperator.from_function(
#     791         definition, DEFAULT_BACKEND if backend is eve.NOTHING else backend, grid_type
#     792     )
# --> 794 return field_operator_inner if definition is None else field_operator_inner(definition)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/decorator.py:790, in field_operator.<locals>.field_operator_inner(definition)
#     789 def field_operator_inner(definition: types.FunctionType) -> FieldOperator[foast.FieldOperator]:
# --> 790     return FieldOperator.from_function(
#     791         definition, DEFAULT_BACKEND if backend is eve.NOTHING else backend, grid_type
#     792     )
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/decorator.py:589, in FieldOperator.from_function(cls, definition, backend, grid_type, operator_node_cls, operator_attributes)
#     587 closure_vars = get_closure_vars_from_function(definition)
#     588 annotations = typing.get_type_hints(definition)
# --> 589 foast_definition_node = FieldOperatorParser.apply(source_def, closure_vars, annotations)
#     590 loc = foast_definition_node.location
#     591 operator_attribute_nodes = {
#     592     key: foast.Constant(value=value, type=type_translation.from_value(value), location=loc)
#     593     for key, value in operator_attributes.items()
#     594 }
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/dialect_parser.py:74, in DialectParser.apply(cls, source_definition, closure_vars, annotations)
#      72 definition_ast = RemoveDocstrings.apply(definition_ast)
#      73 definition_ast = FixMissingLocations.apply(definition_ast)
# ---> 74 output_ast = cls._postprocess_dialect_ast(
#      75     cls(
#      76         source_definition=source_definition,
#      77         closure_vars=closure_vars,
#      78         annotations=annotations,
#      79     ).visit(cls._preprocess_definition_ast(definition_ast)),
#      80     closure_vars,
#      81     annotations,
#      82 )
#      84 return output_ast
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/func_to_foast.py:101, in FieldOperatorParser._postprocess_dialect_ast(cls, foast_node, closure_vars, annotations)
#      99 foast_node = DeadClosureVarElimination.apply(foast_node)
#     100 foast_node = ClosureVarTypeDeduction.apply(foast_node, closure_vars)
# --> 101 foast_node = FieldOperatorTypeDeduction.apply(foast_node)
#     102 foast_node = UnpackedAssignPass.apply(foast_node)
#     104 # check deduced matches annotated return type
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/foast_passes/type_deduction.py:252, in FieldOperatorTypeDeduction.apply(cls, node)
#     250 @classmethod
#     251 def apply(cls, node: foast.FunctionDefinition) -> foast.FunctionDefinition:
# --> 252     typed_foast_node = cls().visit(node)
#     254     FieldOperatorTypeDeductionCompletnessValidator.apply(typed_foast_node)
#     256     return typed_foast_node
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/foast_passes/type_deduction.py:260, in FieldOperatorTypeDeduction.visit_FunctionDefinition(self, node, **kwargs)
#     258 def visit_FunctionDefinition(self, node: foast.FunctionDefinition, **kwargs):
#     259     new_params = self.visit(node.params, **kwargs)
# --> 260     new_body = self.visit(node.body, **kwargs)
#     261     new_closure_vars = self.visit(node.closure_vars, **kwargs)
#     262     return_type = deduce_stmt_return_type(new_body)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:161, in NodeTranslator.generic_visit(self, node, **kwargs)
#     157 memo = kwargs.get("__memo__", None)
#     159 if isinstance(node, concepts.Node):
#     160     new_node = node.__class__(  # type: ignore
# --> 161         **{
#     162             name: new_child
#     163             for name, child in node.iter_children_items()
#     164             if (new_child := self.visit(child, **kwargs)) is not NOTHING
#     165         },
#     166     )
#     167     if self.PRESERVED_ANNEX_ATTRS and (old_annex := getattr(node, "__node_annex__", None)):
#     168         # access to `new_node.annex` implicitly creates the `__node_annex__` attribute in the property getter
#     169         new_annex_dict = new_node.annex.__dict__
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:164, in <dictcomp>(.0)
#     157 memo = kwargs.get("__memo__", None)
#     159 if isinstance(node, concepts.Node):
#     160     new_node = node.__class__(  # type: ignore
#     161         **{
#     162             name: new_child
#     163             for name, child in node.iter_children_items()
# --> 164             if (new_child := self.visit(child, **kwargs)) is not NOTHING
#     165         },
#     166     )
#     167     if self.PRESERVED_ANNEX_ATTRS and (old_annex := getattr(node, "__node_annex__", None)):
#     168         # access to `new_node.annex` implicitly creates the `__node_annex__` attribute in the property getter
#     169         new_annex_dict = new_node.annex.__dict__
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:181, in NodeTranslator.generic_visit(self, node, **kwargs)
#     175     return new_node
#     177 if isinstance(node, (list, tuple, set, collections.abc.Set)) or (
#     178     isinstance(node, collections.abc.Sequence) and not isinstance(node, (str, bytes))
#     179 ):
#     180     # Sequence or set: create a new container instance with the new values
# --> 181     return node.__class__(  # type: ignore
#     182         new_child
#     183         for child in trees.iter_children_values(node)
#     184         if (new_child := self.visit(child, **kwargs)) is not NOTHING
#     185     )
#     187 if isinstance(node, (dict, collections.abc.Mapping)):
#     188     # Mapping: create a new mapping instance with the new values
#     189     return node.__class__(  # type: ignore[call-arg]
#     190         {
#     191             name: new_child
#    (...)
#     194         }
#     195     )
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:184, in <genexpr>(.0)
#     175     return new_node
#     177 if isinstance(node, (list, tuple, set, collections.abc.Set)) or (
#     178     isinstance(node, collections.abc.Sequence) and not isinstance(node, (str, bytes))
#     179 ):
#     180     # Sequence or set: create a new container instance with the new values
#     181     return node.__class__(  # type: ignore
#     182         new_child
#     183         for child in trees.iter_children_values(node)
# --> 184         if (new_child := self.visit(child, **kwargs)) is not NOTHING
#     185     )
#     187 if isinstance(node, (dict, collections.abc.Mapping)):
#     188     # Mapping: create a new mapping instance with the new values
#     189     return node.__class__(  # type: ignore[call-arg]
#     190         {
#     191             name: new_child
#    (...)
#     194         }
#     195     )
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/foast_passes/type_deduction.py:362, in FieldOperatorTypeDeduction.visit_Assign(self, node, **kwargs)
#     360 new_value = node.value
#     361 if not type_info.is_concrete(node.value.type):
# --> 362     new_value = self.visit(node.value, **kwargs)
#     363 new_target = self.visit(node.target, refine_type=new_value.type, **kwargs)
#     364 return foast.Assign(target=new_target, value=new_value, location=node.location)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/foast_passes/type_deduction.py:671, in FieldOperatorTypeDeduction.visit_Call(self, node, **kwargs)
#     669 def visit_Call(self, node: foast.Call, **kwargs) -> foast.Call:
#     670     new_func = self.visit(node.func, **kwargs)
# --> 671     new_args = self.visit(node.args, **kwargs)
#     672     new_kwargs = self.visit(node.kwargs, **kwargs)
#     674     func_type = new_func.type
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:181, in NodeTranslator.generic_visit(self, node, **kwargs)
#     175     return new_node
#     177 if isinstance(node, (list, tuple, set, collections.abc.Set)) or (
#     178     isinstance(node, collections.abc.Sequence) and not isinstance(node, (str, bytes))
#     179 ):
#     180     # Sequence or set: create a new container instance with the new values
# --> 181     return node.__class__(  # type: ignore
#     182         new_child
#     183         for child in trees.iter_children_values(node)
#     184         if (new_child := self.visit(child, **kwargs)) is not NOTHING
#     185     )
#     187 if isinstance(node, (dict, collections.abc.Mapping)):
#     188     # Mapping: create a new mapping instance with the new values
#     189     return node.__class__(  # type: ignore[call-arg]
#     190         {
#     191             name: new_child
#    (...)
#     194         }
#     195     )
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:184, in <genexpr>(.0)
#     175     return new_node
#     177 if isinstance(node, (list, tuple, set, collections.abc.Set)) or (
#     178     isinstance(node, collections.abc.Sequence) and not isinstance(node, (str, bytes))
#     179 ):
#     180     # Sequence or set: create a new container instance with the new values
#     181     return node.__class__(  # type: ignore
#     182         new_child
#     183         for child in trees.iter_children_values(node)
# --> 184         if (new_child := self.visit(child, **kwargs)) is not NOTHING
#     185     )
#     187 if isinstance(node, (dict, collections.abc.Mapping)):
#     188     # Mapping: create a new mapping instance with the new values
#     189     return node.__class__(  # type: ignore[call-arg]
#     190         {
#     191             name: new_child
#    (...)
#     194         }
#     195     )
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/foast_passes/type_deduction.py:512, in FieldOperatorTypeDeduction.visit_BinOp(self, node, **kwargs)
#     511 def visit_BinOp(self, node: foast.BinOp, **kwargs) -> foast.BinOp:
# --> 512     new_left = self.visit(node.left, **kwargs)
#     513     new_right = self.visit(node.right, **kwargs)
#     514     new_type = self._deduce_binop_type(node, left=new_left, right=new_right)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/foast_passes/type_deduction.py:512, in FieldOperatorTypeDeduction.visit_BinOp(self, node, **kwargs)
#     511 def visit_BinOp(self, node: foast.BinOp, **kwargs) -> foast.BinOp:
# --> 512     new_left = self.visit(node.left, **kwargs)
#     513     new_right = self.visit(node.right, **kwargs)
#     514     new_type = self._deduce_binop_type(node, left=new_left, right=new_right)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/foast_passes/type_deduction.py:512, in FieldOperatorTypeDeduction.visit_BinOp(self, node, **kwargs)
#     511 def visit_BinOp(self, node: foast.BinOp, **kwargs) -> foast.BinOp:
# --> 512     new_left = self.visit(node.left, **kwargs)
#     513     new_right = self.visit(node.right, **kwargs)
#     514     new_type = self._deduce_binop_type(node, left=new_left, right=new_right)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/foast_passes/type_deduction.py:671, in FieldOperatorTypeDeduction.visit_Call(self, node, **kwargs)
#     669 def visit_Call(self, node: foast.Call, **kwargs) -> foast.Call:
#     670     new_func = self.visit(node.func, **kwargs)
# --> 671     new_args = self.visit(node.args, **kwargs)
#     672     new_kwargs = self.visit(node.kwargs, **kwargs)
#     674     func_type = new_func.type
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:181, in NodeTranslator.generic_visit(self, node, **kwargs)
#     175     return new_node
#     177 if isinstance(node, (list, tuple, set, collections.abc.Set)) or (
#     178     isinstance(node, collections.abc.Sequence) and not isinstance(node, (str, bytes))
#     179 ):
#     180     # Sequence or set: create a new container instance with the new values
# --> 181     return node.__class__(  # type: ignore
#     182         new_child
#     183         for child in trees.iter_children_values(node)
#     184         if (new_child := self.visit(child, **kwargs)) is not NOTHING
#     185     )
#     187 if isinstance(node, (dict, collections.abc.Mapping)):
#     188     # Mapping: create a new mapping instance with the new values
#     189     return node.__class__(  # type: ignore[call-arg]
#     190         {
#     191             name: new_child
#    (...)
#     194         }
#     195     )
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:184, in <genexpr>(.0)
#     175     return new_node
#     177 if isinstance(node, (list, tuple, set, collections.abc.Set)) or (
#     178     isinstance(node, collections.abc.Sequence) and not isinstance(node, (str, bytes))
#     179 ):
#     180     # Sequence or set: create a new container instance with the new values
#     181     return node.__class__(  # type: ignore
#     182         new_child
#     183         for child in trees.iter_children_values(node)
# --> 184         if (new_child := self.visit(child, **kwargs)) is not NOTHING
#     185     )
#     187 if isinstance(node, (dict, collections.abc.Mapping)):
#     188     # Mapping: create a new mapping instance with the new values
#     189     return node.__class__(  # type: ignore[call-arg]
#     190         {
#     191             name: new_child
#    (...)
#     194         }
#     195     )
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/foast_passes/type_deduction.py:481, in FieldOperatorTypeDeduction.visit_Subscript(self, node, **kwargs)
#     480 def visit_Subscript(self, node: foast.Subscript, **kwargs) -> foast.Subscript:
# --> 481     new_value = self.visit(node.value, **kwargs)
#     482     new_type: Optional[ts.TypeSpec] = None
#     483     match new_value.type:
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/traits.py:168, in VisitorWithSymbolTableTrait.visit(self, node, **kwargs)
#     165     if new_scope := ("symtable" in node.annex):
#     166         kwargs["symtable"] = kwargs["symtable"].new_child(node.annex.symtable)
# --> 168 result = super().visit(node, **kwargs)
#     170 if new_scope:
#     171     kwargs["symtable"] = kwargs["symtable"].parents
#
# File ~/gt4py-update_types/gt4py/src/gt4py/eve/visitors.py:121, in NodeVisitor.visit(self, node, **kwargs)
#     118         if node_class is concepts.Node:
#     119             break
# --> 121 return visitor(node, **kwargs)
#
# File ~/gt4py-update_types/gt4py/src/gt4py/next/ffront/foast_passes/type_deduction.py:354, in FieldOperatorTypeDeduction.visit_Name(self, node, **kwargs)
#     352 symtable = kwargs["symtable"]
#     353 if node.id not in symtable or symtable[node.id].type is None:
# --> 354     raise errors.DSLError(node.location, f"Undeclared symbol '{node.id}'.")
#     356 symbol = symtable[node.id]
#     357 return foast.Name(id=node.id, type=symbol.type, location=node.location)
#
# DSLError: Undeclared symbol 'E2C2V'.
#   File "/private/var/folders/2b/_2y31vzs4sl_7rngh2yghbpw0000gn/T/ipykernel_56953/2481047861.py", line 27

# %%
def test_diffusion_step():
    u = random_field((n_edges), E)
    v = random_field((n_edges), E)
    nx = random_field((n_edges), E)
    ny = random_field((n_edges), E)
    L = random_field((n_edges), E)
    dualL = random_field((n_edges), E)
    A = random_field((n_cells), C)
    dualA = random_field((n_vertices), V)
    edge_orientation_vertex = random_field((n_cells, 6), V, V2EDim)
    edge_orientation_cell = random_field((n_cells, 3), C, C2EDim)

    laplacian_ref = laplacian_numpy(
        c2e_table,
        u.asnumpy(),
        v.asnumpy(),
        nx.asnumpy(),
        ny.asnumpy(),
        L.asnumpy(),
        A.asnumpy(),
        edge_orientation.asnumpy(),
    )

    c2e_connectivity = gtx.NeighborTableOffsetProvider(c2e_table, C, E, 3)

    laplacian_gt4py = zero_field((n_edges), E)

    laplacian_fvm(
        u, v, nx, ny, L, A, edge_orientation, out = divergence_gt4py, offset_provider = {C2E.value: c2e_connectivity}
    )
    
    assert np.allclose(divergence_gt4py.asnumpy(), divergence_ref)

# %%
test_diffusion_step()
print("Test successful")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 test_diffusion_step()
#       2 print("Test successful")
#
# Cell In[9], line 2, in test_diffusion_step()
#       1 def test_diffusion_step():
# ----> 2     u = random_field((n_edges), E)
#       3     v = random_field((n_edges), E)
#       4     nx = random_field((n_edges), E)
#
# File ~/gt4py-update_types/gt4py/docs/user/next/exercises/helpers.py:47, in random_field(domain, low, high, allocator)
#      42 def random_field(
#      43     domain: gtx.Domain, low: float = -1.0, high: float = 1.0, *, allocator=None
#      44 ) -> MutableLocatedField:
#      45     return gtx.as_field(
#      46         domain,
# ---> 47         np.random.default_rng().uniform(low=low, high=high, size=domain.shape),
#      48         allocator=allocator,
#      49     )
#
# AttributeError: 'int' object has no attribute 'shape'
